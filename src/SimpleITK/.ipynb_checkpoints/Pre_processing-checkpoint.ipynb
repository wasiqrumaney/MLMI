# %%
import SimpleITK as sitk
import matplotlib.pyplot as plt
import numpy as np
import os
import torch
import pandas as pd
from skimage import io, transform
from skimage.transform import resize
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils
from utilities.data_utils import *

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Data Loader

# %%
csv_dir='D:/pass/TUM/3rd_ws18-19/MLMI/Dataset/xVertSeg.v1/Data1/scores/scores.csv'
root_dir='D:/pass/TUM/3rd_ws18-19/MLMI/Dataset/xVertSeg.v1/Data1/masks'
 
transformed_dataset = VertSegDataset(csv_file=csv_dir,
                             root_dir=root_dir,
                            transform= transforms.Compose([
                                ISOResample(),
                                MinMaxCrop(),
                                Resize(),
                                transforms.ToTensor()
                            ]))

dataloader = DataLoader(transformed_dataset, batch_size=4,
                         shuffle=True, num_workers=4)
for i_batch, sample_batched in enumerate(dataloader):
    for i in range(sample_batched.shape[0]):
        plot_middle_slices(sample_batched[i])
